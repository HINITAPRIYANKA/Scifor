# %% [markdown]
# <a href="https://colab.research.google.com/github/HINITAPRIYANKA/Scifor/blob/main/NasaAssesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')

# %%
print(df.describe())
# Out:
#              rowid  Default Parameter Flag  Number of Planets in System  \
# count     7.000000                     7.0                          7.0
# mean   7392.142857                     1.0                          7.0
# std       3.532165                     0.0                          0.0
# min    7386.000000                     1.0                          7.0
# 25%    7390.500000                     1.0                          7.0
# 50%    7393.000000                     1.0                          7.0
# 75%    7394.500000                     1.0                          7.0
# max    7396.000000                     1.0                          7.0
#
#        Orbital Period (days)  Orbital Period Upper Unc. (days)  \
# count               7.000000                      7.000000e+00
# mean                7.948793                      2.142887e+00
# std                 6.542524                      5.669454e+00
# min                 1.510871                      6.000000e-07
# ...

# %%
print(df.columns)
# Out:
# Index(['rowid', 'Host Name', 'Letter', 'Default Parameter Flag', 'Reference',
#        'Discovery Method', 'Number of Planets in System',
#        'Orbital Period (days)', 'Orbital Period Upper Unc. (days)',
#        'Orbital Period Lower Unc. (days)', 'Orbital Period Limit Flag',
#        'Orbit Semi-Major Axis (AU)', 'Orbit Semi-Major Axis Upper Unc (AU)',
#        'Orbit Semi-Major Axis Lower Unc (AU)',
#        'Orbit Semi-Major Axis Limit Flag', 'Eccentricity',
#        'Eccentricity Upper Unc.', 'Eccentricity Lower Unc.',
#        'Eccentricity Limit Flag', 'Inclination (deg)',
#        'Inclination Upper Unc. (deg)', 'Inclination Lower Unc. (deg)',
#        'Inclination Limit Flag', 'Planet Mass (Jupiter mass)',
#        'Planet Mass or M*sin(i)Upper Unc. (Jupiter mass)',
#        'Planet Mass or M*sin(i)Lower Unc. (Jupiter mass)',
#        'Planet Mass or M*sin(i) Limit Flag', 'Planet Radius (Jupiter radii)',
#        'Planet Radius Upper Unc. (Jupiter radii)',
# ...

# %%
df.columns = df.columns.str.strip()

# %%
print(df.isnull().sum())
# Out:
# rowid                                               0
# Host Name                                           0
# Letter                                              0
# Default Parameter Flag                              0
# Reference                                           0
# Discovery Method                                    0
# Number of Planets in System                         0
# Orbital Period (days)                               0
# Orbital Period Upper Unc. (days)                    0
# Orbital Period Lower Unc. (days)                    0
# Orbital Period Limit Flag                           0
# Orbit Semi-Major Axis (AU)                          0
# Orbit Semi-Major Axis Upper Unc (AU)                0
# Orbit Semi-Major Axis Lower Unc (AU)                0
# Orbit Semi-Major Axis Limit Flag                    0
# Eccentricity                                        1
# Eccentricity Upper Unc.                             7
# ...

# %%
df.dropna(subset=['Planet Density (g/cm**3)'], inplace=True)

# %%
df['Planet Density (g/cm**3)'] = pd.to_numeric(df['Planet Density (g/cm**3)'], errors = 'coerce')
plt.figure(figsize=(10,6))
sns.scatterplot(x='Eccentricity', y='Planet Density (g/cm**3)', data=df, color='skyblue')
plt.title('Eccentricity vs Planet Density')
plt.xlabel('Eccentricity')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)

# %%
#heatmap
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), cmap='coolwarm')
plt.title('Correlation HeatMap')
plt.show()
